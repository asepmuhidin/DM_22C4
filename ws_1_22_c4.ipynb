# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/DM_22C4/blob/main/ws_1_22_c4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/asepmuhidin/MK-Data-Mining-UPB/refs/heads/main/dataset/cereal.csv'
data=pd.read_csv(url)

# %%
data.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# ...

# %%
data.tail(10)
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 67                Special K   K    C       110        6    0     230    1.0
# 68  Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
# 69        Total Corn Flakes   G    C       110        2    1     200    0.0
# 70        Total Raisin Bran   G    C       140        3    1     190    4.0
# 71        Total Whole Grain   G    C       100        3    1     200    3.0
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# ...

# %%
data.sample(5)
# Out:
#                                 name mfr type  calories  protein  fat  sodium  \
# 50                 Nutri-grain Wheat   K    C        90        3    0     170
# 44  Muesli Raisins; Dates; & Almonds   R    C       150        4    3      95
# 15                         Corn Chex   R    C       110        2    0     280
# 32                 Grape Nuts Flakes   P    C       100        3    1     140
# 24                       Froot Loops   K    C       110        2    1     125
#
#     fiber  carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 50    3.0   18.0     2.0    90.0   FDA_25      3     1.0  1.00  59.642837
# 44    3.0   16.0    11.0   170.0   FDA_25      3     1.0  1.00  37.136863
# 15    0.0   22.0     3.0    25.0   FDA_25      1     1.0  1.00  41.445019
# 32    3.0   15.0     5.0    85.0   FDA_25      3     1.0  0.88  52.076897
# 24    1.0   11.0    13.0    30.0   FDA_25      2     1.0  1.00  32.207582

# %%
#Melihat jenis tipe data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     76 non-null     float64
#  9   sugars    76 non-null     float64
#  10  potass    75 non-null     float64
#  11  vitamins  77 non-null     object
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(7), int64(5), object(4)
# memory usage: 9.8+ KB

# %%
#Melihat data statistik deskriptif
data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass      shelf     weight       cups     rating
# count  76.000000   75.000000  77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   2.207792   1.029610   0.821039  42.665705
# std     4.378656   70.410636   0.832524   0.150477   0.232716  14.047289
# ...
